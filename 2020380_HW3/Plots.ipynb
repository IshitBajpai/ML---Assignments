# %%
import seaborn as sns
import numpy as np

# %%
x_A = [0,1,0]
y_A = [0,0,1]

x_B = [1,2,2]
y_B = [1,2,0]

# %%
sns.scatterplot(x=x_A,y=y_A,label="A")
sns.scatterplot(x=x_B,y=y_B,label="B")
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=x_A,y=y_A,label="A")
sns.scatterplot(x=x_B,y=y_B,label="B")

# x + y = 1.5
sns.lineplot(x=np.array([0,1,1.75,2]),y=1.5-np.array([0,1,1.75,2]))
# Out:
# <AxesSubplot:>
